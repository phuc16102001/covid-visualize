# %% [markdown]
# # Library

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import geopandas as gpd
import numpy as np

from fuzzywuzzy import process
from fuzzywuzzy import fuzz

pd.set_option("display.precision", 3)

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('../data/2022-03-27-clean.csv')
df.head()
# Out:
#   Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# 0           USA   8.162e+07     628.0    1.003e+06        3.0       6.427e+07
# 1         India   4.302e+07       NaN    5.210e+05        NaN       4.248e+07
# 2        Brazil   2.983e+07       NaN    6.588e+05        NaN       2.846e+07
# 3        France   2.492e+07       NaN    1.416e+05        NaN       2.292e+07
# 4            UK   2.069e+07       NaN    1.645e+05        NaN       1.878e+07
#
#    NewRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0           NaN    1.635e+07            2307.0          244102.0
# 1           NaN    1.616e+04            8944.0           30652.0
# 2           NaN    7.089e+05            8318.0          138644.0
# 3           NaN    1.862e+06            1564.0          380314.0
# 4           NaN    1.743e+06             302.0          302049.0
#
#    Deaths/1M pop  TotalTests  Tests/1M pop  Population      Continent
# 0         3001.0   9.783e+08     2.926e+06   3.344e+08  North America
# 1          371.0   7.869e+08     5.607e+05   1.403e+09           Asia
# 2         3062.0   6.378e+07     2.964e+05   2.152e+08  South America
# 3         2162.0   2.541e+08     3.878e+06   6.552e+07         Europe
# 4         2401.0   5.007e+08     7.309e+06   6.850e+07         Europe

# %% [markdown]
# # Z-score

# %%
def z_score(x):
    return (x-x.mean())/x.std()

# %% [markdown]
# # Top 10 Countries With The Most Covid-19 Cases

# %%
top10_total_index = df['TotalCases'].values.argsort()[::-1]
top10_total = df.iloc[top10_total_index[:10]]

plt.figure(figsize=(15,10))
sns.barplot(data=top10_total,x='TotalCases',y='Country,Other',color="salmon")
plt.title("Top 10 Countries With The Most Covid-19 Cases")
plt.ylabel("Country")
plt.xlabel("Total cases")

plt.savefig('../img/fig1.png')
plt.show()

# %% [markdown]
# # Top 10 Countries With The Highest Population-to-Case Ratio

# %%
df_rate_case_pop = df['Population']/df['TotalCases'] 
index = df_rate_case_pop.argsort()[::-1][:10]
top10_rate_case_pop = df.iloc[index]
top10_rate_case_pop['Rate'] = df_rate_case_pop[index]

plt.figure(figsize=(15,10))
sns.barplot(data=top10_rate_case_pop,y='Country,Other',x='Rate', color="salmon")
plt.xlabel("Rate (%)")
plt.ylabel("Country")
plt.title("Rate total population respected to total cases over countries")
plt.savefig("../img/fig2.png")
plt.show()

# %% [markdown]
# # Create dataframe by groupping by continent

# %%
df_continent = df.groupby("Continent").sum()
df_continent = df_continent.reset_index()
df_continent.head()
# Out:
#            Continent  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0             Africa   1.169e+07     151.0    2.524e+05        7.0
# 1               Asia   1.369e+08  501310.0    1.393e+06      970.0
# 2  Australia/Oceania   5.143e+06   57039.0    8.703e+03       17.0
# 3             Europe   1.755e+08  222452.0    1.764e+06      751.0
# 4      North America   9.634e+07    4396.0    1.438e+06      104.0
#
#    TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 0       9.836e+06         296.0    4.989e+05            1422.0
# 1       1.165e+08      286188.0    6.092e+06           26763.0
# 2       4.431e+06       14786.0    6.328e+05             139.0
# 3       1.474e+08      303125.0    1.655e+07           10789.0
# 4       7.731e+07        3558.0    1.758e+07            7931.0
#
#    Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  Population
# 0         1.748e+06        17784.0   9.865e+07     9.944e+06   1.396e+09
# 1         4.874e+06        30539.0   1.840e+09     7.783e+07   3.219e+09
# 2         1.266e+06         5884.0   7.403e+07     1.073e+07   4.325e+07
# 3         1.431e+07       109278.0   2.567e+09     1.896e+08   7.484e+08
# 4         6.090e+06        49475.0   1.094e+09     8.363e+07   5.970e+08

# %% [markdown]
# # Comparing The Number Of Covid-19 Cases Between Continents

# %%
colors = sns.color_palette('pastel')
fig, ax = plt.subplots(1,2,figsize=(20,10))

rate_test_pop_continent = df_continent['TotalTests']/df_continent['Population']
index = rate_test_pop_continent.values.argsort()[::-1]
df_rate_test_pop_continent = df_continent.iloc[index]
df_rate_test_pop_continent['Test/pop'] = rate_test_pop_continent[index]

ax[0].pie(x=df_rate_test_pop_continent['TotalCases'],
            labels=df_rate_test_pop_continent['Continent'],
            autopct='%.0f%%',
            wedgeprops = {'edgecolor':'k', 'linestyle': 'dashed'},
            colors=len(df_rate_test_pop_continent['TotalCases'])*["salmon"])
ax[0].set_title("Total case over continents")

sns.barplot(ax=ax[1],y=df_rate_test_pop_continent['Test/pop'],x=df_rate_test_pop_continent['Continent'],color="salmon")
ax[1].set_title("Rate test respected to population over continents")
ax[1].set_xlabel("Continent")
ax[1].set_ylabel("Rate (%)")

plt.savefig('../img/fig3.png')
plt.show()

# %% [markdown]
# # Pairplot for checking relationship

# %%
sns.pairplot(data=df,vars=['TotalCases','NewCases','TotalDeaths','NewDeaths','TotalRecovered','NewRecovered','ActiveCases','Serious,Critical'],corner=True)
plt.show()

# %% [markdown]
# # Pearson's correlation

# %%
corr = df.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_618fd_row0_col0, #T_618fd_row1_col1, #T_618fd_row2_col2, #T_618fd_row3_col3, #T_618fd_row4_col4, #T_618fd_row5_col5, #T_618fd_row6_col6, #T_618fd_row7_col7, #T_618fd_row8_col8, #T_618fd_row9_col9, #T_618fd_row10_col10, #T_618fd_row11_col11, #T_618fd_row12_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_618fd_row0_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_618fd_row0_col2 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_618fd_row0_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_618fd_row0_col4, #T_618fd_row4_col0 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_618fd_row0_col5 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_618fd_row0_col6 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_618fd_row0_col7 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_618fd_row0_col8 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_618fd_row0_col9, #T_618fd_row10_col11 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_618fd_row0_col10, #T_618fd_row10_col0 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_618fd_row0_col11 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_618fd_row0_col12, #T_618fd_row1_col3 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_618fd_row1_col0, #T_618fd_row3_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_618fd_row1_col2, #T_618fd_row7_col11 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_618fd_row1_col4, #T_618fd_row2_col8 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_618fd_row1_col5 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_618fd_row1_col6, #T_618fd_row3_col2, #T_618fd_row5_col8, #T_618fd_row7_col6 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_618fd_row1_col7 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_618fd_row1_col8 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_618fd_row1_col9, #T_618fd_row11_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_618fd_row1_col10, #T_618fd_row3_col6, #T_618fd_row3_col8, #T_618fd_row3_col9, #T_618fd_row3_col11, #T_618fd_row8_col3, #T_618fd_row8_col7, #T_618fd_row8_col12, #T_618fd_row9_col1, #T_618fd_row9_col5, #T_618fd_row11_col0, #T_618fd_row11_col2, #T_618fd_row11_col4, #T_618fd_row11_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_618fd_row1_col11, #T_618fd_row11_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_618fd_row1_col12 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_618fd_row2_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_618fd_row2_col1, #T_618fd_row5_col11 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_618fd_row2_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_618fd_row2_col4 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_618fd_row2_col5, #T_618fd_row11_col9, #T_618fd_row12_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_618fd_row2_col6, #T_618fd_row4_col7 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_618fd_row2_col7 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_618fd_row2_col9, #T_618fd_row3_col5 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_618fd_row2_col10 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_618fd_row2_col11 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_618fd_row2_col12 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_618fd_row3_col1 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_618fd_row3_col4, #T_618fd_row9_col4 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_618fd_row3_col7 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_618fd_row3_col10, #T_618fd_row8_col10 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_618fd_row3_col12 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_618fd_row4_col1, #T_618fd_row6_col12 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_618fd_row4_col2, #T_618fd_row5_col1 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_618fd_row4_col3 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_618fd_row4_col5 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_618fd_row4_col6 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_618fd_row4_col8, #T_618fd_row6_col9, #T_618fd_row10_col3, #T_618fd_row10_col8 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_618fd_row4_col9 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_618fd_row4_col10 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_618fd_row4_col11 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_618fd_row4_col12, #T_618fd_row10_col12 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_618fd_row5_col0 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_618fd_row5_col2 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_618fd_row5_col3 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_618fd_row5_col4, #T_618fd_row7_col3 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_618fd_row5_col6 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_618fd_row5_col7, #T_618fd_row12_col0 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_618fd_row5_col9 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_618fd_row5_col10 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_618fd_row5_col12 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_618fd_row6_col0 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_618fd_row6_col1 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_618fd_row6_col2 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_618fd_row6_col3 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_618fd_row6_col4 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_618fd_row6_col5 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_618fd_row6_col7 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_618fd_row6_col8, #T_618fd_row10_col9 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_618fd_row6_col10 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_618fd_row6_col11 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_618fd_row7_col0 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_618fd_row7_col1 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_618fd_row7_col2 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_618fd_row7_col4 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_618fd_row7_col5 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_618fd_row7_col8, #T_618fd_row8_col0, #T_618fd_row8_col5, #T_618fd_row8_col6 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_618fd_row7_col9, #T_618fd_row8_col1 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_618fd_row7_col10 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_618fd_row7_col12 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_618fd_row8_col2, #T_618fd_row11_col12 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_618fd_row8_col4, #T_618fd_row9_col3, #T_618fd_row12_col8 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_618fd_row8_col9, #T_618fd_row10_col7 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_618fd_row8_col11 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_618fd_row9_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_618fd_row9_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_618fd_row9_col6, #T_618fd_row9_col10 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_618fd_row9_col7 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_618fd_row9_col8 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_618fd_row9_col11 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_618fd_row9_col12, #T_618fd_row12_col9 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_618fd_row10_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_618fd_row10_col2 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_618fd_row10_col4 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_618fd_row10_col5 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_618fd_row10_col6, #T_618fd_row11_col8 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_618fd_row11_col1 {
#   background-color: #f6eff7;

# %% [markdown]
# # Heatmap of correlation

# %%
plt.figure(figsize=(10,8))
plt.title("Pearson's correlation")
sns.heatmap(corr,cmap='Greys')
plt.show()

# %% [markdown]
# # Sorting correlation of total case

# %%
corr_total_cases = corr['TotalCases']
corr_total_cases = corr_total_cases.sort_values()[::-1]

plt.figure(figsize=(10,8))
sns.barplot(y=corr_total_cases.index,x=corr_total_cases,color='salmon')
plt.show()

# %% [markdown]
# # Death-to-case ratio between countries

# %%
mean = df['Deaths/1M pop'].mean()
median = df['Deaths/1M pop'].median() 

plt.figure(figsize=(10,8))
plt.hist(df['Deaths/1M pop'],bins = len(df)//4, color='salmon')

plt.axvline(mean, color='salmon', linestyle='--', label="Mean")
plt.axvline(median, color='salmon', linestyle='-', label="Median")

plt.legend()
plt.xlabel('Deaths/1M population Histogram')
plt.savefig('../img/fig4.png')
plt.show()

# %% [markdown]
# # Relationship log-log of death and serious

# %%
df['Serious_Log_Std'] = z_score(np.log(df['Serious,Critical']))
df['TotalDeaths_Log_Std'] = z_score(np.log(df['TotalDeaths']))

plt.figure(figsize=(10,8))

sns.regplot(data=df,x='Serious_Log_Std',y='TotalDeaths_Log_Std',color='salmon')
plt.xlabel("Log(Serious)")
plt.ylabel("Log(Death)")
plt.title("Relationship between log-log of death and serious case")

plt.savefig("../img/fig5.png")
plt.show()

# %%
result = smf.ols(' Q("TotalDeaths_Log_Std") ~ Q("Serious_Log_Std")',data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Q("TotalDeaths_Log_Std")   R-squared:                       0.661
# Model:                                  OLS   Adj. R-squared:                  0.658
# Method:                       Least Squares   F-statistic:                     299.7
# Date:                      Sun, 27 Mar 2022   Prob (F-statistic):           5.84e-38
# Time:                              17:36:06   Log-Likelihood:                -131.72
# No. Observations:                       156   AIC:                             267.4
# Df Residuals:                           154   BIC:                             273.5
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.2106      0.045      4.643      0.000       0.121       0.300
# Q("Serious_Log_Std")     0.7878      0.046     17.311      0.000       0.698       0.878
# ==============================================================================
# Omnibus:                       16.745   Durbin-Watson:                   1.438
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.383
# Skew:                          -0.663   Prob(JB):                     2.27e-05
# Kurtosis:                       4.237   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Dead and recovery rate

# %%
df_rate = pd.DataFrame(df['Country,Other'])
df_rate['Dead rate'] = df['TotalDeaths'] / df['TotalCases'] 
df_rate['Recovered rate'] = df['TotalRecovered'] / df['TotalCases'] 

plt.figure(figsize=(10,8))
df_rate = df_rate.melt('Country,Other',var_name='Rate type', value_name='Rate (%)')
sns.swarmplot(data=df_rate,y='Rate (%)',x='Rate type',color='salmon')
plt.title("Dead and recovered rate")
plt.savefig('../img/fig6.png')
plt.show()

# %%
df['TotalCases_Std'] = z_score(df['TotalCases'])
df['TotalDeaths_Std'] = z_score(df['TotalDeaths'])
df['TotalRecovered_Std'] = z_score(df['TotalRecovered'])

result = smf.ols('TotalCases_Std ~ TotalRecovered_Std + TotalDeaths_Std',data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         TotalCases_Std   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     8650.
# Date:                Sun, 27 Mar 2022   Prob (F-statistic):          6.79e-192
# Time:                        17:36:07   Log-Likelihood:                 156.92
# No. Observations:                 199   AIC:                            -307.8
# Df Residuals:                     196   BIC:                            -298.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.0030      0.008      0.379      0.705      -0.013       0.018
# TotalRecovered_Std     1.0025      0.022     46.381      0.000       0.960       1.045
# TotalDeaths_Std        0.0230      0.021      1.076      0.283      -0.019       0.065
# ==============================================================================
# Omnibus:                      117.130   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17651.602
# Skew:                           1.056   Prob(JB):                         0.00
# Kurtosis:                      49.091   Cond. No.                         5.37
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Total test less than total cases

# %%
plt.figure(figsize=(10,8))

df_delta_test_total = df
df_delta_test_total['Delta'] = df['TotalTests']-df['TotalCases']
df_delta_test_total = df_delta_test_total.sort_values(by='Delta',ascending=True)[:5]

ax = sns.barplot(data=df_delta_test_total,x='Country,Other',y='Delta',color='salmon')
ax.axhline(0,color='black')

plt.xlabel("Country")
plt.ylabel("(Total test - Total case)")
plt.title("Difference between total test and total case over countries")
plt.savefig("../img/fig7.png")
plt.show()

# %% [markdown]
# # Define world map

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI   8.374e+03
# 1   53950935         Africa                  Tanzania    TZA   1.506e+05
# 2     603253         Africa                 W. Sahara    ESH   9.065e+02
# 3   35623680  North America                    Canada    CAN   1.674e+06
# 4  326625791  North America  United States of America    USA   1.856e+07
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %% [markdown]
# # Cases on map over countries

# %%
countries = df['Country,Other']

def fuzzy_match(findStr, listAC, nElement=1):
    matches = process.extract(findStr, listAC, limit=nElement, scorer = fuzz.token_sort_ratio)
    return matches

for i, country in enumerate(countries):
    candidates = fuzzy_match(country,world['name'],1)
    if (candidates[0][1]<100 and candidates[0][1]>75):
        print(country,candidates)
        countries[i] = candidates[0][0]

countries.replace("USA","United States of America",inplace=True)
countries.replace("UAE","United Arab Emirates",inplace=True)
countries.replace("UK","United Kingdom",inplace=True)

df['Country'] = countries
df['Rate_case'] = df['Population']/df['TotalCases'] 
world_country = world.merge(df,how='left',left_on='name',right_on='Country')
# Out:
# S. Korea [('South Korea', 78, 96)]
# Dominican Republic [('Dominican Rep.', 84, 17)]
# Bosnia and Herzegovina [('Bosnia and Herz.', 81, 170)]
# South Sudan [('S. Sudan', 78, 176)]
# Dominica [('Dominican Rep.', 76, 17)]
# Solomon Islands [('Solomon Is.', 80, 135)]
# Falkland Islands [('Falkland Is.', 81, 20)]

# %%
fig, ax = plt.subplots(1,1,figsize=(15,8))
world_country.plot(column='TotalCases',ax=ax,legend=True,cmap=sns.color_palette("dark:salmon_r", as_cmap=True),edgecolors='grey')
plt.title("Total cases over countries")
plt.savefig("../img/fig8.png")
plt.show()
